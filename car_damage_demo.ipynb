# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
# Disable Tnsorflow warnings
tf.logging.set_verbosity(tf.logging.ERROR)

# import inference code
from car_damage import Inference, Inference_Multi

# Enable plotting in notebook
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# Set up file paths
image_path = "datasets/car_damage/val/0133.JPEG" # Input Image path
weights_path = "mask_rcnn_car_damage_0030.h5" # pre-trained model weights path

# Inference on new image
result = Inference(weights_path, image_path)

# show the results
img = cv2.imread(image_path) # raw input image
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
fig = plt.figure(figsize=(15, 10))

plt.subplot(1, 2, 1)
plt.imshow(img)

plt.subplot(1, 2, 2)
plt.imshow(result)
plt.show()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.9
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# ...

# %%
# process all imeges
Inference_Multi(weights_path, "datasets/car_damage/val/", verbose=1, batch_size=5)
# Out:
# Processing 5 images
# image                    shape: (194, 259, 3)         min:    4.00000  max:  255.00000  uint8
# image                    shape: (197, 256, 3)         min:    0.00000  max:  255.00000  uint8
# image                    shape: (194, 259, 3)         min:    0.00000  max:  255.00000  uint8
# image                    shape: (194, 259, 3)         min:    0.00000  max:  255.00000  uint8
# image                    shape: (194, 259, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (5, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (5, 14)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (5, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# Processing 5 images
# image                    shape: (194, 259, 3)         min:    0.00000  max:  255.00000  uint8
# ...
